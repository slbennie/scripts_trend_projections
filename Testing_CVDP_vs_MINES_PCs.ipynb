# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
cvdp = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/CVDP_outputs/NAO/historical/historical_NAO/CanESM5_r10i1p1f1.cvdp_data.1850-2014.nc')
cvdp['nao_timeseries_djf'].plot()

# %%
ds = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/projection_indicies/NAO/historical/CanESM5/psl_mon_historical_CanESM5_r10i1p1f1_DJF_NAO_index_norm.nc')
ds2 = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/EOF/historical/DJF/normalised_aligned_neg/CanESM5/psl_mon_historical_CanESM5_r10i1p1f1_DJF_EOF_indiv_1850-2014.nc')

(ds2['PCs'].sel(mode=0)).plot()
cvdp['nao_timeseries_djf'].plot()
#ds['psl'].plot()
#(ds2['PCs'].sel(mode=0)).plot()
print(ds2)
plt.show()
# Out:
# <xarray.Dataset> Size: 47kB
# Dimensions:      (mode: 2, lat: 25, lon: 53, time: 165)
# Coordinates:
#   * mode         (mode) int64 16B 0 1
#   * lat          (lat) float64 200B 20.0 22.5 25.0 27.5 ... 72.5 75.0 77.5 80.0
#   * lon          (lon) float64 424B -90.0 -87.5 -85.0 -82.5 ... 35.0 37.5 40.0
#   * time         (time) int64 1kB 1850 1851 1852 1853 ... 2011 2012 2013 2014
#     season       <U3 12B ...
# Data variables:
#     eofs         (mode, lat, lon) float64 21kB ...
#     PCs          (mode, time) float64 3kB ...
#     regressions  (mode, lat, lon) float64 21kB ...
# Attributes:
#     model:        CanESM5
#     experiment:   historical
#     member_id:    r10i1p1f1
#     description:  EOF, PC, and regression map per ensemble member.\nEOFs are ...
