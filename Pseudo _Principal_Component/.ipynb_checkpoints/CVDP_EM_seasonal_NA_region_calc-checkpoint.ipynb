# %%
#following code only needs to be run once for each season - can build up once I am doing lots of different models etc.
#right now just getting the hitorical ensemble mean djf and saving that for further use in projecting_anomaly_onto_pattern_ipynb

# %%
#Only needs to be run once afterwards can just open the file
#The NAO pattern from the ensemble mean, also in Pa/Pa?
#need to shift the coordinates or like stitch for the NA region.
ds = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/CVDP_outputs/NAO/historical/historical_NAO/HadGEM3-GC31-LL_EM.cvdp_data.nao.1850-2014.nc')
ds = ds['nao_pattern_djf_em']

#finding the longitudes that are greater than 180
new_lon = np.where(ds.lon > 179, ds.lon -360, ds.lon)

#creating a copy of the data array where the longitudes have been shifted
ds_shifted = ds.copy()
ds_shifted.coords['lon'] = new_lon

#Now need to make sure they are in the correct order and then re-index to make sure the lon get put to match the sorted lon
sorted_lon = np.sort(ds_shifted.lon)
ds_shifted = ds_shifted.sel(lon=sorted_lon)

historical_NAO_EM_shifted = ds_shifted.sel(lat=slice(20,80), lon=slice(-90,40))

historical_NAO_EM_shifted.to_netcdf('/gws/nopw/j04/extant/users/slbennie/psl_anomalies/historical/HadGEM3-GC31-LL/CVDP_historical_NAO_HadGEM3-GC31-LL_EM_djf_1850-2014.nc')

historical_NAO_EM = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/psl_anomalies/historical/HadGEM3-GC31-LL/CVDP_historical_NAO_HadGEM3-GC31-LL_EM_djf_1850-2014.nc')
historical_NAO_EM

# %%
import xarray as xr
import numpy as np
def CVDP_EM_crop_NA_sector(filename, pattern, output_file):
    #function which will crop the historical ensemble mean CVDP output to the NA sector
    ds = xr.open_dataset(filename)
    ds = ds[pattern]
    
    #finding the longitudes that are greater than 180
    new_lon = np.where(ds.lon > 179, ds.lon -360, ds.lon)
    
    #creating a copy of the data array where the longitudes have been shifted
    ds_shifted = ds.copy()
    ds_shifted.coords['lon'] = new_lon
    
    #Now need to make sure they are in the correct order and then re-index to make sure the lon get put to match the sorted lon
    sorted_lon = np.sort(ds_shifted.lon)
    ds_shifted = ds_shifted.sel(lon=sorted_lon)
    
    historical_NAO_EM_shifted = ds_shifted.sel(lat=slice(20,80), lon=slice(-90,40))

    return historical_NAO_EM_shifted

# %%
historical_NAO_EM = CVDP_EM_crop_NA_sector('/gws/nopw/j04/extant/users/slbennie/CVDP_outputs/NAO/historical/historical_NAO/HadGEM3-GC31-LL_EM.cvdp_data.nao.1850-2014.nc', 'nao_pattern_djf_em', '/gws/nopw/j04/extant/users/slbennie/psl_anomalies/historical/HadGEM3-GC31-LL/CVDP_historical_NAO_HadGEM3-GC31-LL_EM_djf_1850-2014.nc')

historical_NAO_EM
# Out:
# <xarray.DataArray 'nao_pattern_djf_em' (lat: 25, lon: 53)> Size: 5kB
# [1325 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float64 200B 20.0 22.5 25.0 27.5 30.0 ... 72.5 75.0 77.5 80.0
#   * lon      (lon) float64 424B -90.0 -87.5 -85.0 -82.5 ... 32.5 35.0 37.5 40.0
# Attributes:
#     nens:       50
#     long_name:  NAO spatial pattern (DJF) Ensemble Mean
#     pcvar:      40.6%*
#     units:      hPa
