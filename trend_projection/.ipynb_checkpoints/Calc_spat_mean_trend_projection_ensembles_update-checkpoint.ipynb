# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os
import cftime
import pandas as pd
from datetime import datetime
import matplotlib.colors as mcolors
from scipy.stats import linregress
from eofs.xarray import Eof
from eofs.examples import example_data_path

# %%
#getting the correct calendar (model dependent.)
def get_time_bounds(calendar_type, start, end):
    #1850-2015 all of 2014 - none of 2015.
    if calendar_type == cftime.DatetimeNoLeap:
        return cftime.DatetimeNoLeap(start,1,16), cftime.DatetimeNoLeap(end,1,16)
    elif calendar_type == cftime.Datetime360Day:
        return cftime.Datetime360Day(start,1,16), cftime.Datetime360Day(end-1,12,16)
    else:
        return datetime(start,1,16), datetime(end,1,16)

#finding all the models that have ensembles for that experiment.
def get_models_for_experiment(experiment):
    if experiment == 'historical':
        model = ['ACCESS-ESM1-5','CanESM5','CMCC-CM2-SR5','FGOALS-g3','GISS-E2-1-G','HadGEM3-GC31-LL','IPSL-CM6A-LR','MIROC6','MPI-ESM1-2-LR','NorESM2-LM']
    elif experiment == 'hist-aer':
        model = ['ACCESS-ESM1-5','CanESM5','CMCC-CM2-SR5','CNRM-CM6-1','FGOALS-g3','GISS-E2-1-G','HadGEM3-GC31-LL','IPSL-CM6A-LR','MIROC6','MPI-ESM1-2-LR','NorESM2-LM']
    elif experiment == 'hist-GHG':
        model = ['ACCESS-ESM1-5','CanESM5','CMCC-CM2-SR5','CNRM-CM6-1','FGOALS-g3','GISS-E2-1-G','HadGEM3-GC31-LL','IPSL-CM6A-LR','MIROC6','MPI-ESM1-2-LR','NorESM2-LM']
    elif experiment == 'hist-sol':
        model = ['ACCESS-ESM1-5','CanESM5','GISS-E2-1-G','HadGEM3-GC31-LL','MIROC6','MPI-ESM1-2-LR','NorESM2-LM']
    elif experiment == 'hist-totalO3':
        model = ['CanESM5','GISS-E2-1-G','HadGEM3-GC31-LL','MIROC6','MPI-ESM1-2-LR','NorESM2-LM']
    elif experiment == 'hist-volc':
        model = ['ACCESS-ESM1-5','CanESM5','CMCC-CM2-SR5','GISS-E2-1-G','HadGEM3-GC31-LL','MIROC6','MPI-ESM1-2-LR','NorESM2-LM']
        
    return model

#Cropping CVDP data to the North Atlantic sector - requires some shifting of 0 of the lat lon coordinate system.
def CVDP_EM_crop_NA_sector(filename, pattern):
    #function which will crop the historical ensemble mean CVDP output to the NA sector
    ds = xr.open_dataset(filename)
    ds = ds[pattern]
    
    #finding the longitudes that are greater than 180
    new_lon = np.where(ds.lon > 179, ds.lon -360, ds.lon)
    
    #creating a copy of the data array where the longitudes have been shifted
    ds_shifted = ds.copy()
    ds_shifted.coords['lon'] = new_lon
    
    #Now need to make sure they are in the correct order and then re-index to make sure the lon get put to match the sorted lon
    sorted_lon = np.sort(ds_shifted.lon)
    ds_shifted = ds_shifted.sel(lon=sorted_lon)
    
    historical_NAO_EM_shifted = ds_shifted.sel(lat=slice(20,80), lon=slice(-90,40))

    return historical_NAO_EM_shifted

#Crops to the North Atlantic sector - for the LESFMIP data NOT processed by CVDP
def open_cropNA_unitshPA(filename):
    #function to crop an ensemble member to the north atlantic region
    data = xr.open_dataset(filename)
    data_NA = data.sel(lat=slice(20,80), lon=slice(-90,40))/100

    return data_NA

# %%
#calculating the seasonal and annual ensemble spatial means.

def calculate_spatial_ensemble_mean(file_paths, output_file, variable):
    #Will be passing through an experiment's model's ensembles.
    #opens all the files given by filepath (basically opens all the ensembles)
    ds = xr.open_mfdataset(file_paths, combine='nested', concat_dim='ensemble')

    #calculate the mean
    mean = ds[variable].mean(dim='ensemble')

    #save the ensemble mean to the a .nc file
    mean.to_netcdf(output_file)
    print('saved')

    ds.close()
    return mean

def calculate_seasonal_spatial_ensemble_mean_djf(file_path, var, seas, output_file, year_init, year_final):
    #opening dataset
    print('in function')
    ds = xr.open_dataset(file_path)
    
    #checking it is a datetime object
    ds['time'] = xr.decode_cf(ds).time

    calendar = type(ds.time.values[0])
    
    start,end = get_time_bounds(calendar, year_init, year_final)

    #selecting the psl variable within time bounds
    variable = ds[var].sel(time=slice(start, end))
    
    #Filter for the desired season (e.g., DJF)
    season_mask = variable.time.dt.season == seas
    ds_months_seas = variable.sel(time=season_mask)
    
    #assign and adjust year (DJF split over two years so increasing the year of december and then grouping and finding the mean)
    ds_months_seas = ds_months_seas.assign_coords(year=ds_months_seas['time'].dt.year)
    ds_months_seas['year'] = ds_months_seas['year'].where(ds_months_seas['time'].dt.month != 12, ds_months_seas['year'] + 1)
    #ds_months_seas = ds_months_seas.set_coords('year')
    
    # average over DJF months for each year
    ds_season = ds_months_seas.groupby('year').mean(dim='time')
    ds_season.to_netcdf(output_file)
    print('saved file')
    return ds_season

# %%
#functions defined for calculating the linear trend
def calculate_linear_trend_spat_pattern(file_path, variable, output_file):
    # Open dataset and extract variable
    ds = xr.open_dataset(file_path)
    da = ds[variable]

    time = ds['year'].values
    lat = ds['lat'].values
    lon = ds['lon'].values
    time_numeric = np.arange(len(time))

    slope = np.full((len(lat), len(lon)), np.nan)
    intercept = np.full((len(lat), len(lon)), np.nan)
    p_value = np.full((len(lat), len(lon)), np.nan)
    stderr = np.full((len(lat), len(lon)), np.nan)

    for i in range(len(lat)):
        for j in range(len(lon)):
            ts = da[:, i, j].values
            if np.all(np.isfinite(ts)):
                reg = linregress(time_numeric, ts)
                slope[i, j] = reg.slope
                intercept[i, j] = reg.intercept
                p_value[i, j] = reg.pvalue
                stderr[i, j] = reg.stderr

    from scipy.stats import t
    n = len(time_numeric)
    df = n - 2
    alpha = 0.05
    t_crit = t.ppf(1 - alpha/2, df)

    ci_lower = slope - t_crit * stderr
    ci_upper = slope + t_crit * stderr

    slope_da = xr.DataArray(slope, coords=[lat, lon], dims=["lat", "lon"], name="slope")
    intercept_da = xr.DataArray(intercept, coords=[lat, lon], dims=["lat", "lon"], name="intercept")
    p_value_da = xr.DataArray(p_value, coords=[lat, lon], dims=["lat", "lon"], name="p_value")
    ci_lower_da = xr.DataArray(ci_lower, coords=[lat, lon], dims=["lat", "lon"], name="slope_CI_lower")
    ci_upper_da = xr.DataArray(ci_upper, coords=[lat, lon], dims=["lat", "lon"], name="slope_CI_upper")

    # Save to one combined netCDF file
    combined_ds = xr.Dataset({
        "slope": slope_da,
        "intercept": intercept_da,
        "p_value": p_value_da,
        "slope_CI_lower": ci_lower_da,
        "slope_CI_upper": ci_upper_da
    })
    combined_ds.to_netcdf(output_file)

# %%
def calculate_regression_map(anomalies, mode, e, m, period, era5=False, individual=False):
    #function that will calculculate the regression map and EOF for either individual ensemble members or a stack of ensemble members
    #select mode number
    mode_number = 0 if mode == 'NAO' else 1

    #preprocess anomalies
    anomaly_list = [open_cropNA_unitshPA(f) for f in anomalies]

    if individual:
        #calculating it for each ensemble member
        for i, da in enumerate(anomaly_list):
            print('calculating the individual ensembles')
            psl = da['psl']

            #creating the weights
            wgts = np.sqrt(np.cos(np.deg2rad(psl.coords['lat'].values)))[..., np.newaxis]
            psl_stacked = psl.rename({'year': 'time'}).transpose('time', 'lat', 'lon')

            #creating the EOF solver
            solver = Eof(psl_stacked, weights=wgts)

            #extracting the EOF pattern
            EOF_pattern = solver.eofs(neofs=mode_number+1).sel(mode=mode_number)

            #Finding the PC adn then normalising (could just keep pcscaling=1 as PC is normalised)
            pc = solver.pcs(npcs=mode_number+1, pcscaling=1).sel(mode=mode_number)
            #pc = (pc - pc.mean()) / pc.std()

            #calculating the regression map by regressing the psl anomalies onto the pc
            regression_map = (psl_stacked * pc).mean(dim='time')

            # Sign convention correction
            #ensures Icelandic Low is negative and EA main centre is also negative.
            if mode == 'NAO':

                if regression_map.sel(lat=50, lon=-30, method='nearest') > 0 and \
                   regression_map.sel(lat=35, lon=-15, method='nearest') < 0:
                    regression_map *= -1
                    pc *= -1

            elif mode == 'EA':
 
                if regression_map.sel(lat=50, lon=-25, method='nearest') > 0 and \
                   regression_map.sel(lat=30, lon=0, method='nearest') < 0:
                    regression_map *= -1
                    pc *= -1
                
            output = anomalies[i].replace('/psl_anomalies', '/regression_patterns/'+mode)

            if m == 'era5':
                #creating the filenames for EOF and regression maps for both era5 data (slightly different filepath and naming)
                output_regression_map = output.replace('anomalies_1940-2024', mode+'_regression_map_'+period)
                output_EOF = output.replace('anomalies_1940-2024', period+'_EOF')
            else:
                output_regression_map = output.replace('anomaly', mode+'_regression_map_'+period)
                output_EOF = output.replace('anomaly', period+'_EOF')

            print(output_regression_map)
            
            regression_map.name = 'regression_'+mode+'_djf'
            regression_map.to_netcdf(output_regression_map)
            
            EOF_pattern.name = 'EOF_'+mode+'_djf'
            EOF_pattern.to_netcdf(output_EOF)

    else:
        print('calculating the mean regression map')
        all_anomalies = xr.concat(anomaly_list, dim='ensemble')['psl']  # (ensemble, year, lat, lon)
        all_anomalies_stacked = all_anomalies.stack(time=('ensemble', 'year')).reset_index('time', drop=True)
        all_anomalies_stacked = all_anomalies_stacked.transpose('time', 'lat', 'lon')

        coslat = np.cos(np.deg2rad(all_anomalies_stacked.coords['lat'].values)).clip(0., 1.)
        wgts = np.sqrt(coslat)[..., np.newaxis]

        print("Shape of all_anomalies_stacked:", all_anomalies_stacked.shape)

        solver = Eof(all_anomalies_stacked, weights=wgts)
        EOF_pattern = solver.eofs(neofs=mode_number+1).sel(mode=mode_number)
        pc = solver.pcs(npcs=mode_number+1, pcscaling=0).sel(mode=mode_number)
        pc = (pc - pc.mean()) / pc.std()
        regression_map = (all_anomalies_stacked * pc).mean(dim='time')

        # Sign convention correction
        #ensures Icelandic Low is negative and EA main centre is also negative.
        if mode == 'NAO':

            if regression_map.sel(lat=70, lon=-30, method='nearest') > 0 and \
               regression_map.sel(lat=35, lon=-15, method='nearest') < 0:
                regression_map *= -1
                pc *= -1

        elif mode == 'EA':

            if regression_map.sel(lat=50, lon=-25, method='nearest') > 0 and \
               regression_map.sel(lat=30, lon=0, method='nearest') < 0:
                regression_map *= -1
                pc *= -1
                
        output_regression_map = '/gws/nopw/j04/extant/users/slbennie/regression_patterns/'+mode+'/'+e+'/'+m+'/psl_mon_'+e+'_'+m+'_DJF_'+mode+'_regression_map_'+period+'.nc'
        output_EOF = '/gws/nopw/j04/extant/users/slbennie/regression_patterns/'+mode+'/'+e+'/'+m+'/psl_mon_'+e+'_'+m+'_DJF_'+mode+'_EOF_pattern_'+period+'.nc'

        regression_map.name = 'regression_'+mode+'_djf'
        regression_map.to_netcdf(output_regression_map)
            
        EOF_pattern.name = 'EOF_'+mode+'_djf'
        EOF_pattern.to_netcdf(output_EOF)

# %%
#functions defined for calculating the projections
def project_onto_regression(trend_raw, regression_map, trend_var, mode, e, m, period):
    #function which will project a trend (lat,lon) in hPa onto a spatial pattern (lat,lon) hPa to get a single NAO index value
    #will then calculate the residual (trend - mode_congruent part) and saves both the NAO congruent part and the residual
    #in the same folder, output_file is for the NAO/EA_congruent part filename
    #can then change the input spat pattern to calculate the projection onto other eofs, e.g. the EAP


    if isinstance(trend_raw, xr.DataArray):
        trend = trend_raw
    else:
        print('here')
        trend = trend_raw[trend_var]
        
    # Weight psl data by coslat to account for grid cell area decreasing with latitude
    weights = np.cos(np.radians(trend["lat"].values))
    weights_2d = weights[:, np.newaxis]

    # weight psl (or another variable) anomalies by area of each gridcell
    weighted_trend = trend * weights_2d
    weighted_regression = regression_map * weights_2d

    # flatten both of the fields so that they are both 1D
    trend_flat = weighted_trend.stack(spatial=('lat','lon'))
    regression_flat = weighted_regression.stack(spatial=('lat','lon'))

    #replace any NaNs with zeros to stop any weird stuff happening
    trend_flat = trend_flat.fillna(0)
    regression_flat = regression_flat.fillna(0)

    #Now do the dot product which is the projection
    dot_product = (trend_flat * regression_flat).sum().item()

    #calculating the index - or I guess the PC?????
    index = dot_product / (regression_flat**2).sum().item()

    #Now multiplying the pattern by the index and returning that too
    projection = (index * regression_map)
    residual = trend - projection
    
    projection.name = 'projection_'+mode+'_djf'
    residual.name = 'residual_'+mode+'_djf'

    output_projection = '/gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/'+e+'/'+m+'/psl_mon_'+e+'_'+m+'_DJF_'+mode+'_projection_'+period+'.nc'
    output_residual = '/gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/'+e+'/'+m+'/psl_mon_'+e+'_'+m+'_DJF_'+mode+'_residual_'+period+'.nc'
    
    #outputting .nc files for plotting
    projection.to_netcdf(output_projection)
    residual.to_netcdf(output_residual)
    
    return projection, residual

# %%
era5 = ['/gws/nopw/j04/extant/users/slbennie/psl_anomalies/era5/era5_DJF_anomalies_1940-2024.nc']
period = '1940-2024'

def open_cropNA_unitshPA(filename):
    #function to crop an ensemble member to the north atlantic region
    data = xr.open_dataset(filename)
    data_NA = data.sel(lat=slice(20,80), lon=slice(-90,40))/100

    return data_NA

cropped = open_cropNA_unitshPA(era5[0])

calculate_regression_map(era5, modes[0], 'historical', 'era5', period, individual=True)
calculate_regression_map(era5, modes[1], 'historical', 'era5', period, individual=True)
# Out:
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/era5/era5_DJF_NAO_regression_map_1940-2024.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/era5/era5_DJF_EA_regression_map_1940-2024.nc

# %%
home = '/gws/nopw/j04/extant/users/slbennie/'


variable = 'psl'
period = '1850-2015'
#experiments = ['historical', 'hist-aer', 'hist-GHG', 'hist-sol','hist-totalO3','hist-volc']
model = ['HadGEM3-GC31-LL']
modes = ['NAO','EA']
seas = 'DJF'

for m in model:
    #REGRESSION MAPS
    print('Calculating the regression map for model:', m)
    #path to the folder containing historical experiment and model's psl anomalies (calculated seperatley)
    folder_path = f'{home}psl_anomalies/historical/{m}/'

    #creating the list of files for this experiment and model's psl anomalies
    ens_files = [os.path.join(folder_path, filename) for filename in os.listdir(folder_path) if m in filename and '_EM' not in filename]

    calculate_regression_map(ens_files, modes[0], 'historical', m, period, individual=True)
    calculate_regression_map(ens_files, modes[1], 'historical', m, period, individual=True)

    calculate_regression_map(ens_files, modes[0], 'historical', m, period, individual=False)
    calculate_regression_map(ens_files, modes[1], 'historical', m, period, individual=False)
# Out:
# Calculating the regression map for model: HadGEM3-GC31-LL
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r11i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r12i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r13i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r14i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r15i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r16i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r17i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r18i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r19i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r1i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r20i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r21i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r22i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r23i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r24i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r25i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r26i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r27i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r28i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r29i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r2i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r30i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r31i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r32i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r33i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r34i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r35i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r36i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r37i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r38i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r39i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r3i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r40i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r41i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r42i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r43i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r44i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r45i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r46i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r47i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r48i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r49i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r4i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r50i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r51i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r52i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r53i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r54i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r55i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r56i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r57i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r58i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r59i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r5i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r60i1p1f3_DJF_NAO_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r11i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r12i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r13i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r14i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r15i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r16i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r17i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r18i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r19i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r1i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r20i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r21i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r22i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r23i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r24i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r25i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r26i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r27i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r28i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r29i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r2i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r30i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r31i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r32i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r33i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r34i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r35i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r36i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r37i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r38i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r39i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r3i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r40i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r41i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r42i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r43i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r44i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r45i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r46i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r47i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r48i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r49i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r4i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r50i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r51i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r52i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r53i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r54i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r55i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r56i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r57i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r58i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r59i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r5i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the individual ensembles
# /gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r60i1p1f3_DJF_EA_regression_map_1850-2015.nc
# calculating the mean regression map
# Shape of all_anomalies_stacked: (9075, 25, 53)
# calculating the mean regression map
# Shape of all_anomalies_stacked: (9075, 25, 53)

# %%
era5 = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/era5/era5_DJF_EA_regression_map_1940-2024.nc')
era5['regression_EA_djf'].plot()
plt.show()
ds = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r11i1p1f3_DJF_EA_regression_map_1850-2015.nc')
ds['regression_EA_djf'].plot()
plt.show()
ds2 = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/psl_mon_historical_HadGEM3-GC31-LL_DJF_EA_regression_map_1850-2015.nc')
ds2['regression_EA_djf'].plot()
plt.show()
(ds['regression_EA_djf']-ds2['regression_EA_djf']).plot()
plt.show()

# %%
era5 = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/era5/era5_DJF_NAO_regression_map_1940-2024.nc')
era5['regression_NAO_djf'].plot()
plt.show()
ds = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r11i1p1f3_DJF_NAO_regression_map_1850-2015.nc')
ds['regression_NAO_djf'].plot()
plt.show()
(era5['regression_NAO_djf'] - ds['regression_NAO_djf']).plot()
plt.show()
ds2 = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/psl_mon_historical_HadGEM3-GC31-LL_DJF_NAO_regression_map_1850-2015.nc')
ds2['regression_NAO_djf'].plot()
plt.show()
ds3 = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_DJF_NAO_regression_map_1850-2015.nc')
ds3['regression_NAO_djf'].plot()
plt.show()
(ds['regression_NAO_djf']+ds2['regression_NAO_djf']).plot()
plt.show()

# %%
folder_path = '/gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/'
ens_files = [os.path.join(folder_path, filename) for filename in os.listdir(folder_path) if 'regression_map' in filename]
#print(ens_files)

# Load and sum the datasets
sum_ds = None

for f in ens_files:
    ds = xr.open_dataset(f)
    # Assuming the main variable is named like 'regression_NAO_djf'
    var_name = list(ds.data_vars)[0]  # grabs the variable name dynamically

    if sum_ds is None:
        sum_ds = ds[var_name].copy(deep=True)
    else:
        sum_ds += ds[var_name]

# sum_ds is now the total sum of all regression patterns
# To get the mean, just divide:
mean_ds = sum_ds / len(ens_files)
    
#ds = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/HadGEM3-GC31-LL/psl_mon_historical_HadGEM3-GC31-LL_r11i1p1f3_DJF_NAO_regression_map_1850-2015.nc')
#ds['regression_NAO_djf'].plot()
#plt.show()

# %%
mean_ds.plot()

# %%
ds2 = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/psl_mon_historical_HadGEM3-GC31-LL_DJF_NAO_regression_map_1850-2015.nc')


NAO = ds2['regression_NAO_djf'].sel(lon=slice(-90,0), lat=slice(20,80))

NAO.plot()

plt.show()

CVDP = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/CVDP_outputs/NAO/historical/historical_NAO/HadGEM3-GC31-LL_EM.cvdp_data.nao.1850-2014.nc')
CVDP['nao_pattern_djf_em'].sel(lon=slice(270,360), lat=slice(20,80)).plot()
plt.show()

CVDP = CVDP['nao_pattern_djf_em'].sel(lon=slice(270,360), lat=slice(20,80))

# %%
xr.corr(mean_ds, -ds2['regression_NAO_djf'], dim=['lat', 'lon'])
# Out:
# <xarray.DataArray 'regression_NAO_djf' ()> Size: 8B
# array(0.99667183)
# Coordinates:
#     season   <U3 12B 'DJF'
#     mode     int64 8B 0
