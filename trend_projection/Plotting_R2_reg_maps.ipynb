# %%
import numpy as np
import os
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib.colors as mcolors
import matplotlib.path as mpath
from matplotlib.ticker import MaxNLocator
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.patches as mpatches

# %%
def load_trend_data(variable, model, experiment, period):
    #loads in the trend data
    #factor to convert trend data from Pa/year to hPa
    conversion_factor = 1.65
    
    #slice trend to the N. Atlantic
    lat_range = slice(20, 80)
    lon_range = slice(-90, 40)
    
    filepath = f"{base_dir}/trend_calc_LESFMIP/linear_regression/NAO/{experiment}/{model}/psl_mon_{experiment}_{model}_DJF_linear_trend_{period}_stats.nc"
    if not os.path.exists(filepath):
        print(f"File not found: {filepath}, skipping...")
        return None  # return None if file is missing

    return xr.open_dataset(filepath).sel(lat=lat_range, lon=lon_range) * conversion_factor

def load_proj_or_resid_data(variable, result, mode, model, experiment, period):
    #loads in the projected or residual data
    #mode is NAO/EA, result is proj/res
    filepath = f"{base_dir}/projection_indicies/NAtlantic_forced_trends/{experiment}/{model}/psl_mon_{experiment}_{model}_DJF_{mode}_{result}_{period}.nc"

    if not os.path.exists(filepath):
        print(f"File not found: {filepath}, skipping...")
        return None
            
    return xr.open_dataset(filepath)

def load_reg_pattern(mode, model, experiment, period):
    filepath = f"{base_dir}/regression_patterns/{mode}/psl_mon_{experiment}_{model}_DJF_{mode}_regression_map_{period}.nc"
    return xr.open_dataset(filepath)

def get_min_max(data_dict, variable):
    #finds the max and min values of the data
    values_min = [np.min(data[variable]) for data in data_dict.values()]
    values_max = [np.max(data[variable]) for data in data_dict.values()]
    return min(values_min), max(values_max)

# %%
#once ran for all models could be good to link with the plots - e.g. either save this or calculate with the other plots
#and like generate each plot.
#base directory/home directory
base_dir = '/gws/nopw/j04/extant/users/slbennie'

#time to find the right files
#also time that is right for the plots
period = '1850-2015'
period_title = '1850-2014'

#creating lists for models, exp and modes.
models = ['ACCESS-ESM1-5', 'CanESM5', 'CMCC-CM2-SR5', 'FGOALS-g3', 'GISS-E2-1-G', 'HadGEM3-GC31-LL', 'IPSL-CM6A-LR', 'MIROC6', 'MPI-ESM1-2-LR', 'NorESM2-LM']
experiments = ['historical', 'hist-aer', 'hist-GHG', 'hist-sol', 'hist-totalO3', 'hist-volc']
modes = ['NAO', 'EA']

#Initialize an empty array to store r2 scores:
#Dimensions: model x experiment x mode
r2_array = np.full((len(models), len(experiments), len(modes)), np.nan)

for i_m, m in enumerate(models):
    #loading in the data
    # skip if any dataset is missing
    
    trend_data = {e: load_trend_data('psl', m, e, period) for e in experiments}
    proj_data_NAO = {e: load_proj_or_resid_data('psl', 'projection', 'NAO', m, e, period) for e in experiments}
    proj_data_EA  = {e: load_proj_or_resid_data('psl', 'projection', 'EA', m, e, period) for e in experiments}

    #finding the r^2 values
    for i_e, e in enumerate(experiments):
        if trend_data[e] is None or proj_data_NAO[e] is None or proj_data_EA[e] is None:
            print(f"Skipping {m} {e} due to missing file")
            continue

        trend_array = trend_data[e]['slope'].values.flatten()
        trend_total_variance = np.sum(trend_array ** 2)

        proj_NAO = proj_data_NAO[e]['projection_NAO_djf'].values.flatten()
        proj_EA = proj_data_EA[e]['projection_EA_djf'].values.flatten()

        r2_NAO = np.sum(proj_NAO ** 2) / trend_total_variance
        r2_EA = np.sum(proj_EA ** 2) / trend_total_variance

        r2_array[i_m, i_e, 0] = r2_NAO  # NAO mode
        r2_array[i_m, i_e, 1] = r2_EA   # EA mode

#Create xarray DataArray
r2_scores = xr.DataArray(
    r2_array,
    coords={
        'model': models,
        'experiment': experiments,
        'mode': modes
    },
    dims=['model', 'experiment', 'mode'],
    name='r_squared'
)

# Example: print r² for all
#print(r2_scores)
# Out:
# File not found: /gws/nopw/j04/extant/users/slbennie/trend_calc_LESFMIP/linear_regression/NAO/hist-totalO3/ACCESS-ESM1-5/psl_mon_hist-totalO3_ACCESS-ESM1-5_DJF_linear_trend_1850-2015_stats.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-totalO3/ACCESS-ESM1-5/psl_mon_hist-totalO3_ACCESS-ESM1-5_DJF_NAO_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-totalO3/ACCESS-ESM1-5/psl_mon_hist-totalO3_ACCESS-ESM1-5_DJF_EA_projection_1850-2015.nc, skipping...
# Skipping ACCESS-ESM1-5 hist-totalO3 due to missing file
# File not found: /gws/nopw/j04/extant/users/slbennie/trend_calc_LESFMIP/linear_regression/NAO/hist-sol/CMCC-CM2-SR5/psl_mon_hist-sol_CMCC-CM2-SR5_DJF_linear_trend_1850-2015_stats.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/trend_calc_LESFMIP/linear_regression/NAO/hist-totalO3/CMCC-CM2-SR5/psl_mon_hist-totalO3_CMCC-CM2-SR5_DJF_linear_trend_1850-2015_stats.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-sol/CMCC-CM2-SR5/psl_mon_hist-sol_CMCC-CM2-SR5_DJF_NAO_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-totalO3/CMCC-CM2-SR5/psl_mon_hist-totalO3_CMCC-CM2-SR5_DJF_NAO_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-sol/CMCC-CM2-SR5/psl_mon_hist-sol_CMCC-CM2-SR5_DJF_EA_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-totalO3/CMCC-CM2-SR5/psl_mon_hist-totalO3_CMCC-CM2-SR5_DJF_EA_projection_1850-2015.nc, skipping...
# Skipping CMCC-CM2-SR5 hist-sol due to missing file
# Skipping CMCC-CM2-SR5 hist-totalO3 due to missing file
# File not found: /gws/nopw/j04/extant/users/slbennie/trend_calc_LESFMIP/linear_regression/NAO/hist-sol/FGOALS-g3/psl_mon_hist-sol_FGOALS-g3_DJF_linear_trend_1850-2015_stats.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/trend_calc_LESFMIP/linear_regression/NAO/hist-totalO3/FGOALS-g3/psl_mon_hist-totalO3_FGOALS-g3_DJF_linear_trend_1850-2015_stats.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/trend_calc_LESFMIP/linear_regression/NAO/hist-volc/FGOALS-g3/psl_mon_hist-volc_FGOALS-g3_DJF_linear_trend_1850-2015_stats.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-sol/FGOALS-g3/psl_mon_hist-sol_FGOALS-g3_DJF_NAO_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-totalO3/FGOALS-g3/psl_mon_hist-totalO3_FGOALS-g3_DJF_NAO_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-volc/FGOALS-g3/psl_mon_hist-volc_FGOALS-g3_DJF_NAO_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-sol/FGOALS-g3/psl_mon_hist-sol_FGOALS-g3_DJF_EA_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-totalO3/FGOALS-g3/psl_mon_hist-totalO3_FGOALS-g3_DJF_EA_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-volc/FGOALS-g3/psl_mon_hist-volc_FGOALS-g3_DJF_EA_projection_1850-2015.nc, skipping...
# Skipping FGOALS-g3 hist-sol due to missing file
# Skipping FGOALS-g3 hist-totalO3 due to missing file
# Skipping FGOALS-g3 hist-volc due to missing file
# File not found: /gws/nopw/j04/extant/users/slbennie/trend_calc_LESFMIP/linear_regression/NAO/hist-sol/IPSL-CM6A-LR/psl_mon_hist-sol_IPSL-CM6A-LR_DJF_linear_trend_1850-2015_stats.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/trend_calc_LESFMIP/linear_regression/NAO/hist-totalO3/IPSL-CM6A-LR/psl_mon_hist-totalO3_IPSL-CM6A-LR_DJF_linear_trend_1850-2015_stats.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/trend_calc_LESFMIP/linear_regression/NAO/hist-volc/IPSL-CM6A-LR/psl_mon_hist-volc_IPSL-CM6A-LR_DJF_linear_trend_1850-2015_stats.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-sol/IPSL-CM6A-LR/psl_mon_hist-sol_IPSL-CM6A-LR_DJF_NAO_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-totalO3/IPSL-CM6A-LR/psl_mon_hist-totalO3_IPSL-CM6A-LR_DJF_NAO_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-volc/IPSL-CM6A-LR/psl_mon_hist-volc_IPSL-CM6A-LR_DJF_NAO_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-sol/IPSL-CM6A-LR/psl_mon_hist-sol_IPSL-CM6A-LR_DJF_EA_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-totalO3/IPSL-CM6A-LR/psl_mon_hist-totalO3_IPSL-CM6A-LR_DJF_EA_projection_1850-2015.nc, skipping...
# File not found: /gws/nopw/j04/extant/users/slbennie/projection_indicies/NAtlantic_forced_trends/hist-volc/IPSL-CM6A-LR/psl_mon_hist-volc_IPSL-CM6A-LR_DJF_EA_projection_1850-2015.nc, skipping...
# Skipping IPSL-CM6A-LR hist-sol due to missing file
# Skipping IPSL-CM6A-LR hist-totalO3 due to missing file
# Skipping IPSL-CM6A-LR hist-volc due to missing file

# %%
modes = ['NAO', 'EA']
models = r2_scores.coords['model'].values
experiments = r2_scores.coords['experiment'].values

marker_styles = ['o', 's', '^', 'D', 'v', 'P', '*', 'X', 'h', '1']
model_markers = {model: marker_styles[i % len(marker_styles)] for i, model in enumerate(models)}

fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

for i, mode in enumerate(modes):
    ax = axes[i]
    for model in models:
        # Extract r² values
        y = r2_scores.sel(model=model, mode=mode).values

        # Skip nan values
        x = np.array(experiments)
        mask = ~np.isnan(y)
        x_masked = x[mask]
        y_masked = y[mask]

        ax.scatter(x_masked, y_masked, marker=model_markers[model], label=model, s=100)

    ax.set_title(f"R² for {mode} Mode ({period_title})", fontsize=20)
    if i==0:
        ax.set_ylabel("R² value", fontsize=18)
    if i==1:
        ax.legend(loc='upper right', fontsize=12)
    ax.set_xlabel("Experiment", fontsize=18)
    ax.set_xticks(range(len(experiments)))
    ax.set_xticklabels(experiments, rotation=45, ha='right', fontsize=14)
    ax.tick_params(axis='y', labelsize=14)


plt.tight_layout()
plt.savefig('Figures/R2_all_models.png', bbox_inches='tight')
plt.show()

# %%
modes = ['NAO', 'EA']
models = r2_scores.coords['model'].values
experiments = r2_scores.coords['experiment'].values

# Define a list of unique markers (as many as your number of models)
marker_styles = ['o', 's', '^', 'D', 'v', 'P', '*', 'X', 'h', '1']

# Map each model to a unique marker
model_markers = {model: marker_styles[i % len(marker_styles)] for i, model in enumerate(models)}

fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

for i, mode in enumerate(modes):
    ax = axes[i]
    for model in models:
        # Extract r² values
        y = r2_scores.sel(model=model, mode=mode).values
        # Use the model-specific marker
        ax.scatter(experiments, y, marker=model_markers[model], label=model, s=100)

    ax.set_title(f"R² for {mode} Mode ({period_title})", fontsize=20)
    if i==0:
        ax.set_ylabel("R² value", fontsize=18)
    ax.set_xlabel("Experiment", fontsize=18)
    ax.set_xticks(range(len(experiments)))
    ax.set_xticklabels(experiments, rotation=45, ha='right', fontsize=14)
    ax.tick_params(axis='y', labelsize=14)
    ax.legend(loc='upper right', fontsize=12)

plt.tight_layout()
plt.savefig('Figures/R2_all_models.png', bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/axis.py:1811, in Axis.convert_units(self, x)
#    1810 try:
# -> 1811     ret = self._converter.convert(x, self.units, self)
#    1812 except Exception as e:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/category.py:57, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
# ---> 57 unit.update(values)
#      58 s = np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/category.py:217, in UnitData.update(self, data)
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# --> 217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/_api/__init__.py:92, in check_isinstance(types, **kwargs)
#      91     names.append("None")
# ---> 92 raise TypeError(
#      93     "{!r} must be an instance of {}, not a {}".format(
#      94         k,
#      95         ", ".join(names[:-1]) + " or " + names[-1]
#      96         if len(names) > 1 else names[0],
#      97         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[11], line 31
#      28     ax.legend(loc='upper right', fontsize=12)
#      30 plt.tight_layout()
# ---> 31 plt.savefig('Figures/R2_all_models.png', bbox_inches='tight')
#      32 plt.show()
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/backend_bases.py:2155, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2152     # we do this instead of `self.figure.draw_without_rendering`
#    2153     # so that we can inject the orientation
#    2154     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155         self.figure.draw(renderer)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/axes/_base.py:3216, in _AxesBase.draw(self, renderer)
#    3213 if artists_rasterized:
#    3214     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3216 mimage._draw_list_compositing_images(
#    3217     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3219 renderer.close_group('axes')
#    3220 self.stale = False
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/collections.py:1008, in _CollectionWithSizes.draw(self, renderer)
#    1005 @artist.allow_rasterization
#    1006 def draw(self, renderer):
#    1007     self.set_sizes(self._sizes, self.get_figure(root=True).dpi)
# -> 1008     super().draw(renderer)
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/collections.py:360, in Collection.draw(self, renderer)
#     356 renderer.open_group(self.__class__.__name__, self.get_gid())
#     358 self.update_scalarmappable()
# --> 360 transform, offset_trf, offsets, paths = self._prepare_points()
#     362 gc = renderer.new_gc()
#     363 self._set_gc_clip(gc)
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/collections.py:332, in Collection._prepare_points(self)
#     330     ys = self.convert_yunits(ys)
#     331     paths.append(mpath.Path(np.column_stack([xs, ys]), path.codes))
# --> 332 xs = self.convert_xunits(offsets[:, 0])
#     333 ys = self.convert_yunits(offsets[:, 1])
#     334 offsets = np.ma.column_stack([xs, ys])
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:278, in Artist.convert_xunits(self, x)
#     276 if ax is None or ax.xaxis is None:
#     277     return x
# --> 278 return ax.xaxis.convert_units(x)
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/axis.py:1813, in Axis.convert_units(self, x)
#    1811     ret = self._converter.convert(x, self.units, self)
#    1812 except Exception as e:
# -> 1813     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1814                                  f'units: {x!r}') from e
#    1815 return ret
#
# ConversionError: Failed to convert value(s) to axis units: masked_array(data=[--, --, --, --, --, --],
#              mask=[ True,  True,  True,  True,  True,  True],
#        fill_value=1e+20,
#             dtype=float64)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/axis.py:1811, in Axis.convert_units(self, x)
#    1810 try:
# -> 1811     ret = self._converter.convert(x, self.units, self)
#    1812 except Exception as e:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/category.py:57, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
# ---> 57 unit.update(values)
#      58 s = np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/category.py:217, in UnitData.update(self, data)
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# --> 217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/_api/__init__.py:92, in check_isinstance(types, **kwargs)
#      91     names.append("None")
# ---> 92 raise TypeError(
#      93     "{!r} must be an instance of {}, not a {}".format(
#      94         k,
#      95         ", ".join(names[:-1]) + " or " + names[-1]
#      96         if len(names) > 1 else names[0],
#      97         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# File /opt/jaspy/lib/python3.12/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File /opt/jaspy/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/backend_bases.py:2155, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2152     # we do this instead of `self.figure.draw_without_rendering`
#    2153     # so that we can inject the orientation
#    2154     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155         self.figure.draw(renderer)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/axes/_base.py:3216, in _AxesBase.draw(self, renderer)
#    3213 if artists_rasterized:
#    3214     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3216 mimage._draw_list_compositing_images(
#    3217     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3219 renderer.close_group('axes')
#    3220 self.stale = False
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/collections.py:1008, in _CollectionWithSizes.draw(self, renderer)
#    1005 @artist.allow_rasterization
#    1006 def draw(self, renderer):
#    1007     self.set_sizes(self._sizes, self.get_figure(root=True).dpi)
# -> 1008     super().draw(renderer)
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/collections.py:360, in Collection.draw(self, renderer)
#     356 renderer.open_group(self.__class__.__name__, self.get_gid())
#     358 self.update_scalarmappable()
# --> 360 transform, offset_trf, offsets, paths = self._prepare_points()
#     362 gc = renderer.new_gc()
#     363 self._set_gc_clip(gc)
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/collections.py:332, in Collection._prepare_points(self)
#     330     ys = self.convert_yunits(ys)
#     331     paths.append(mpath.Path(np.column_stack([xs, ys]), path.codes))
# --> 332 xs = self.convert_xunits(offsets[:, 0])
#     333 ys = self.convert_yunits(offsets[:, 1])
#     334 offsets = np.ma.column_stack([xs, ys])
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/artist.py:278, in Artist.convert_xunits(self, x)
#     276 if ax is None or ax.xaxis is None:
#     277     return x
# --> 278 return ax.xaxis.convert_units(x)
#
# File /opt/jaspy/lib/python3.12/site-packages/matplotlib/axis.py:1813, in Axis.convert_units(self, x)
#    1811     ret = self._converter.convert(x, self.units, self)
#    1812 except Exception as e:
# -> 1813     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1814                                  f'units: {x!r}') from e
#    1815 return ret
#
# ConversionError: Failed to convert value(s) to axis units: masked_array(data=[--, --, --, --, --, --],
#              mask=[ True,  True,  True,  True,  True,  True],
#        fill_value=1e+20,
#             dtype=float64)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(25,8), subplot_kw={'projection': ccrs.PlateCarree()})
cmap = 'seismic'

print(models[0])
NAO_pattern = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/regression_patterns/NAO/historical/'+models[0]+'/psl_mon_historical_'+models[0]+'_DJF_NAO_regression_map_'+period+'.nc')
EA_pattern = xr.open_dataset('/gws/nopw/j04/extant/users/slbennie/regression_patterns/EA/historical/'+models[0]+'/psl_mon_historical_'+models[0]+'_DJF_EA_regression_map_'+period+'.nc')

min_NAO = np.min(NAO_pattern['regression_NAO_djf'].values)
max_NAO = np.max(NAO_pattern['regression_NAO_djf'].values)

min_EA = np.min(EA_pattern['regression_EA_djf'].values)
max_EA = np.max(EA_pattern['regression_EA_djf'].values)

min_pattern = min(min_NAO, min_EA)
max_pattern = max(max_NAO, max_EA)

lon_NAO = NAO_pattern['lon'].values
lat_NAO = NAO_pattern['lat'].values

lon_EA = EA_pattern['lon'].values
lat_EA = EA_pattern['lat'].values

print(min_pattern,max_pattern)

norm_pattern = mcolors.TwoSlopeNorm(vmin=min_pattern, vcenter=0, vmax=max_pattern)
levels = np.arange(-5.2,5.6,0.4)


#dummy_data = np.array([[min_EOF, max_EOF], [min_EOF, max_EOF]])
#dummy_cont = ax[0].contourf([0,1], [0,1], dummy_data, cmap=cmap, norm=norm_EOF)#, levels=levels)
#norm_pattern = norm_all

# Map extent
lon_min, lon_max = -90, 40
lat_min, lat_max = 20, 80

# Plot
for i in range(2):
    #)
    ax[i].set_xlabel('lon')
    ax[i].set_ylabel('lat')
    ax[i].add_feature(cfeature.COASTLINE, linewidth=1, edgecolor='black')
    ax[i].set_extent([lon_min, lon_max, lat_min, lat_max], crs=ccrs.PlateCarree())
    ax[i].set_aspect('auto')

# Add colorbar (reusing dummy contour is still fine)

contour = ax[0].contourf(lon_NAO, lat_NAO, (-1*NAO_EOF['regression_NAO_djf']).squeeze(), cmap=cmap, norm=norm_pattern, levels=levels, transform=ccrs.PlateCarree())
ax[1].contourf(lon_EA, lat_EA, EA_EOF['regression_EA_djf'].squeeze(), cmap=cmap, norm=norm_pattern, levels=levels, transform=ccrs.PlateCarree())

cax = fig.add_axes([0.01, -0.1, 0.9, 0.1])
cbar = fig.colorbar(contour, cax=cax, orientation='horizontal')
cbar.set_label('hPa/unit PC', fontsize=22)
cbar.ax.tick_params(direction='in', length=10, width=2, labelsize=22)
ax[0].set_title('North Atlantic Oscillation', fontsize=26)
ax[0].set_title('a)', loc='left', fontsize=26)
ax[1].set_title('East Atlantic Pattern', fontsize=26)
ax[1].set_title('b)', loc='left', fontsize=26)


# Add overall labels and title
fig.suptitle(f"Regression patterns for {model[0]}'s historical experiment ({period_title})", fontsize=30)
plt.tight_layout(rect=[0,0,0.91,0.97])
plt.savefig(f'Figures/NAO_EA_regression_patterns_{model[0]}_{period_title}.png', bbox_inches='tight')
plt.show()
# Out:
# HadGEM3-GC31-LL
# -4.741853571465333 4.124283494351493
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 48
#      44     ax[i].set_aspect('auto')
#      46 # Add colorbar (reusing dummy contour is still fine)
# ---> 48 contour = ax[0].contourf(lon_NAO, lat_NAO, (-1*NAO_EOF['regression_NAO_djf']).squeeze(), cmap=cmap, norm=norm_pattern, levels=levels, transform=ccrs.PlateCarree())
#      49 ax[1].contourf(lon_EA, lat_EA, EA_EOF['regression_EA_djf'].squeeze(), cmap=cmap, norm=norm_pattern, levels=levels, transform=ccrs.PlateCarree())
#      51 cax = fig.add_axes([0.01, -0.1, 0.9, 0.1])
#
# NameError: name 'NAO_EOF' is not defined
